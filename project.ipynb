# %% [markdown]
# ### NAME: IZEHAR MENSAH
# ### INDEX NUMBER: 11327800
# ### DEPARTMENT: BIOMEDICAL ENGINEERING

# %%
import pandas 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pandas.read_csv('red_wine.CSV')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# To find the mean of the columns in the DataFrame

# %%
mean_FA= dataset['fixed acidity'].mean()
mean_VA= dataset['volatile acidity'].mean()
mean_CA= dataset['citric acid'].mean()
mean_RS= dataset['residual sugar'].mean()
mean_C= dataset['chlorides'].mean()
mean_FSD= dataset['free sulfur dioxide'].mean()
mean_TSD= dataset['total sulfur dioxide'].mean()
mean_D= dataset['density'].mean()
mean_PH= dataset['pH'].mean()
mean_S= dataset['sulphates'].mean()
mean_A= dataset['alcohol'].mean()
mean_Q= dataset['quality'].mean()

# %%
print(f'fixed acidity: {mean_FA}')
print(f'volatile acidity: {mean_VA}')
print(f'citric acid: {mean_CA}')
print(f'residual sugar: {mean_RS}')
print(f'chlorides: {mean_C}')
print(f'free sulpur dioxide: {mean_FSD}')
print(f'total sulphur dioxide: {mean_TSD}')
print(f'density: {mean_D}')
print(f'pH: {mean_PH}')
print(f'sulphates: {mean_S}')
print(f'alcohol: {mean_A}')
print(f'quality: {mean_Q}')
# Out:
# fixed acidity: 8.318335419274094
# volatile acidity: 0.527747183979975
# citric acid: 0.2709756097560976
# residual sugar: 2.53880550343965
# chlorides: 0.08747586206896552
# free sulpur dioxide: 15.867334167709638
# total sulphur dioxide: 46.46779237023139
# density: 0.996745519399249
# pH: 3.3111131957473416
# sulphates: 0.6581488430268917
# alcohol: 10.422983114446529
# quality: 5.635794743429287

# %%
# To find the mode of columns in the DataFrame

# %%
mode_FA= dataset['fixed acidity'].mode()
mode_VA= dataset['volatile acidity'].mode()
mode_CA= dataset['citric acid'].mode()
mode_RS= dataset['residual sugar'].mode()
mode_C= dataset['chlorides'].mode()
mode_FSD= dataset['free sulfur dioxide'].mode()
mode_TSD= dataset['total sulfur dioxide'].mode()
mode_D= dataset['density'].mode()
mode_PH= dataset['pH'].mode()
mode_S= dataset['sulphates'].mode()
mode_A= dataset['alcohol'].mode()
mode_Q= dataset['quality'].mode()

# %%
print(f'fixed acidity:{mode_FA}')
print(f'volatile acidity:{mode_VA}')
print(f'citric acid:{mode_CA}')
print(f'residual sugar:{mode_RS}')
print(f'chlorides:{mode_C}')
print(f'free sulpur dioxide:{mode_FSD}')
print(f'total sulphur dioxide:{mode_TSD}')
print(f'density:{mode_D}')
print(f'pH:{mode_PH}')
print(f'sulphates:{mode_S}')
print(f'alcohol:{mode_A}')
print(f'quality:{mode_Q}')
# Out:
# fixed acidity:0    7.2
# Name: fixed acidity, dtype: float64
# volatile acidity:0    0.6
# Name: volatile acidity, dtype: float64
# citric acid:0    0.0
# Name: citric acid, dtype: float64
# residual sugar:0    2.0
# Name: residual sugar, dtype: float64
# chlorides:0    0.08
# Name: chlorides, dtype: float64
# free sulpur dioxide:0    6.0
# Name: free sulfur dioxide, dtype: float64
# total sulphur dioxide:0    28.0
# Name: total sulfur dioxide, dtype: float64
# density:0    0.9972
# Name: density, dtype: float64
# pH:0    3.3
# Name: pH, dtype: float64
# sulphates:0    0.6
# Name: sulphates, dtype: float64
# alcohol:0    9.5
# Name: alcohol, dtype: float64
# quality:0    5.0
# Name: quality, dtype: float64

# %%
# To find the median of the columns in the DataFrame

# %%
median_FA= dataset['fixed acidity'].median()
median_VA= dataset['volatile acidity'].median()
median_CA= dataset['citric acid'].median()
median_RS= dataset['residual sugar'].median()
median_C= dataset['chlorides'].median()
median_FSD= dataset['free sulfur dioxide'].median()
median_TSD= dataset['total sulfur dioxide'].median()
median_D= dataset['density'].median()
median_PH= dataset['pH'].median()
median_S= dataset['sulphates'].median()
median_A= dataset['alcohol'].median()
median_Q= dataset['quality'].median()

# %%
print(f'fixed acidity: {median_FA}')
print(f'volatile acidity: {median_VA}')
print(f'citric acid: {median_CA}')
print(f'residual sugar: {median_RS}')
print(f'chlorides: {median_C}')
print(f'free sulpur dioxide: {median_FSD}')
print(f'total sulphur dioxide: {median_TSD}')
print(f'density: {median_D}')
print(f'pH: {median_PH}')
print(f'sulphates: {median_S}')
print(f'alcohol: {median_A}')
print(f'quality: {median_Q}')
# Out:
# fixed acidity: 7.9
# volatile acidity: 0.52
# citric acid: 0.26
# residual sugar: 2.2
# chlorides: 0.079
# free sulpur dioxide: 14.0
# total sulphur dioxide: 38.0
# density: 0.99675
# pH: 3.31
# sulphates: 0.62
# alcohol: 10.2
# quality: 6.0

# %%
# Filling the empty spaces in each column with the mean values of the respective columns

# %%
dataset['fixed acidity']= dataset['fixed acidity'].fillna(mean_FA) 
dataset['volatile acidity']= dataset['volatile acidity'].fillna(mean_VA) 
dataset['citric acid']= dataset['citric acid'].fillna(mean_CA) 
dataset['residual sugar']= dataset['residual sugar'].fillna(mean_RS) 
dataset['chlorides']= dataset['chlorides'].fillna(mean_C) 
dataset['free sulphur dioxide']= dataset['free sulfur dioxide'].fillna(mean_FSD) 
dataset['total sulphur dioxide']= dataset['total sulfur dioxide'].fillna(mean_TSD) 
dataset['density']= dataset['density'].fillna(mean_D) 
dataset['pH']= dataset['pH'].fillna(mean_PH) 
dataset['sulphates']= dataset['sulphates'].fillna(mean_S) 
dataset['alcohol']= dataset['alcohol'].fillna(mean_A) 
dataset['quality']= dataset['quality'].fillna(mean_Q)

# %%
x= dataset
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fixed acidity          1599 non-null   float64
#  1   volatile acidity       1599 non-null   float64
#  2   citric acid            1599 non-null   float64
#  3   residual sugar         1599 non-null   float64
#  4   chlorides              1599 non-null   float64
#  5   free sulfur dioxide    1598 non-null   float64
#  6   total sulfur dioxide   1599 non-null   float64
#  7   density                1599 non-null   float64
#  8   pH                     1599 non-null   float64
#  9   sulphates              1599 non-null   float64
#  10  alcohol                1599 non-null   float64
#  11  quality                1599 non-null   float64
#  12  free sulphur dioxide   1599 non-null   float64
#  13  total sulphur dioxide  1599 non-null   float64
# dtypes: float64(14)
# ...

# %%
# Filling the empty spaces in each column with the mode of the respective columns

# %%
dataset['fixed acidity']= dataset['fixed acidity'].fillna(mode_FA) 
dataset['volatile acidity']= dataset['volatile acidity'].fillna(mode_VA) 
dataset['citric acid']= dataset['citric acid'].fillna(mode_CA) 
dataset['residual sugar']= dataset['residual sugar'].fillna(mode_RS) 
dataset['chlorides']= dataset['chlorides'].fillna(mode_C) 
dataset['free sulphur dioxide']= dataset['free sulfur dioxide'].fillna(mode_FSD) 
dataset['total sulphur dioxide']= dataset['total sulfur dioxide'].fillna(mode_TSD) 
dataset['density']= dataset['density'].fillna(mode_D) 
dataset['pH']= dataset['pH'].fillna(mode_PH) 
dataset['sulphates']= dataset['sulphates'].fillna(mode_S) 
dataset['alcohol']= dataset['alcohol'].fillna(mode_A) 
dataset['quality']= dataset['quality'].fillna(mode_Q)

# %%
y = dataset
y
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fixed acidity          1599 non-null   float64
#  1   volatile acidity       1599 non-null   float64
#  2   citric acid            1599 non-null   float64
#  3   residual sugar         1599 non-null   float64
#  4   chlorides              1599 non-null   float64
#  5   free sulfur dioxide    1598 non-null   float64
#  6   total sulfur dioxide   1599 non-null   float64
#  7   density                1599 non-null   float64
#  8   pH                     1599 non-null   float64
#  9   sulphates              1599 non-null   float64
#  10  alcohol                1599 non-null   float64
#  11  quality                1599 non-null   float64
#  12  free sulphur dioxide   1599 non-null   float64
#  13  total sulphur dioxide  1599 non-null   float64
# dtypes: float64(14)
# ...

# %%
# Filling the empty spaces in each column with the median of the respective columns

# %%
dataset['fixed acidity']= dataset['fixed acidity'].fillna(median_FA) 
dataset['volatile acidity']= dataset['volatile acidity'].fillna(median_VA) 
dataset['citric acid']= dataset['citric acid'].fillna(median_CA) 
dataset['residual sugar']= dataset['residual sugar'].fillna(median_RS) 
dataset['chlorides']= dataset['chlorides'].fillna(median_C) 
dataset['free sulphur dioxide']= dataset['free sulfur dioxide'].fillna(median_FSD) 
dataset['total sulphur dioxide']= dataset['total sulfur dioxide'].fillna(median_TSD) 
dataset['density']= dataset['density'].fillna(median_D) 
dataset['pH']= dataset['pH'].fillna(median_PH) 
dataset['sulphates']= dataset['sulphates'].fillna(median_S) 
dataset['alcohol']= dataset['alcohol'].fillna(median_A) 
dataset['quality']= dataset['quality'].fillna(median_Q)

# %%
z =  dataset
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fixed acidity          1599 non-null   float64
#  1   volatile acidity       1599 non-null   float64
#  2   citric acid            1599 non-null   float64
#  3   residual sugar         1599 non-null   float64
#  4   chlorides              1599 non-null   float64
#  5   free sulfur dioxide    1598 non-null   float64
#  6   total sulfur dioxide   1599 non-null   float64
#  7   density                1599 non-null   float64
#  8   pH                     1599 non-null   float64
#  9   sulphates              1599 non-null   float64
#  10  alcohol                1599 non-null   float64
#  11  quality                1599 non-null   float64
#  12  free sulphur dioxide   1599 non-null   float64
#  13  total sulphur dioxide  1599 non-null   float64
# dtypes: float64(14)
# ...

# %%
# For more insight into the  DataFrame we will first remove duplicates
# I will focus on the mean-fully-filled DataFrame , same applicable for the mode and median

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
# I will now remove the duplicates

# %%
dataset_duplicates= dataset.drop_duplicates()
dataset_duplicates
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Filtering out columns of your choice

# %%
dataset_duplicates
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset_duplicates.filter(items=['fixed acidity' ,'quality'])
# Out:
#       fixed acidity  quality
# 0               7.4      5.0
# 1               7.8      5.0
# 2               7.8      5.0
# 3              11.2      6.0
# 5               7.4      5.0
# ...             ...      ...
# 1593            6.8      6.0
# 1594            6.2      5.0
# 1595            5.9      6.0
# 1597            5.9      5.0
# 1598            6.0      6.0
#
# [1360 rows x 2 columns]

# %%
dataset_duplicates.filter(['alcohol','free sulfur dioxide'])
# Out:
#       alcohol  free sulfur dioxide
# 0         9.4                 11.0
# 1         9.8                 25.0
# 2         9.8                 15.0
# 3         9.8                 17.0
# 5         9.4                 13.0
# ...       ...                  ...
# 1593      9.5                 28.0
# 1594     10.5                 32.0
# 1595     11.2                 39.0
# 1597     10.2                 32.0
# 1598     11.0                 18.0
#
# [1360 rows x 2 columns]

# %%
dataset_duplicates.filter(like='sulfur')
# Out:
#       free sulfur dioxide  total sulfur dioxide
# 0                    11.0                  34.0
# 1                    25.0                  67.0
# 2                    15.0                  54.0
# 3                    17.0                  60.0
# 5                    13.0                  40.0
# ...                   ...                   ...
# 1593                 28.0                  38.0
# 1594                 32.0                  44.0
# 1595                 39.0                  51.0
# 1597                 32.0                  44.0
# 1598                 18.0                  42.0
#
# [1360 rows x 2 columns]

# %%
# Sorting out the columns in ascending or descending order

# %%
dataset_duplicates.sort_values('quality')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1478            7.1             0.875         0.05             5.7      0.082
# 517            10.4             0.610         0.49             2.1      0.200
# 1299            7.6             1.580         0.00             2.1      0.137
# 832            10.4             0.440         0.42             1.5      0.145
# 459            11.6             0.580         0.66             2.2      0.074
# ...             ...               ...          ...             ...        ...
# 481             9.4             0.300         0.56             2.8      0.080
# 1449            7.2             0.380         0.31             2.0      0.056
# 1120            7.9             0.540         0.34             2.5      0.076
# 278            10.3             0.320         0.45             6.4      0.073
# 828             7.8             0.570         0.09             2.3      0.065
#
# ...

# %%
dataset_duplicates.sort_values('citric acid', ascending=True)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 818             7.1             0.715         0.00            2.35      0.071
# 820             7.0             0.685         0.00            1.90      0.099
# 821             4.9             0.420         0.00            2.10      0.048
# 841             6.6             0.660         0.00            3.00      0.115
# ...             ...               ...          ...             ...        ...
# 258             7.7             0.410         0.76            1.80      0.611
# 395            12.0             0.370         0.76            4.20      0.066
# 1574            5.6             0.310         0.78           13.90      0.074
# 353            13.5             0.530         0.79            4.80      0.120
# 151             9.2             0.520         1.00            3.40      0.610
#
# ...

# %%
# Finding the correlation of the respective columns

# %%
dataset_duplicates.corr()
# Out:
#                        fixed acidity  volatile acidity  citric acid  \
# fixed acidity               1.000000         -0.253679     0.666754
# volatile acidity           -0.253679          1.000000    -0.550037
# citric acid                 0.666754         -0.550037     1.000000
# residual sugar              0.110855         -0.002313     0.143677
# chlorides                   0.085835          0.054840     0.209866
# free sulfur dioxide        -0.139734         -0.020591    -0.048004
# total sulfur dioxide       -0.102660          0.072334     0.047944
# density                     0.669677          0.024102     0.359296
# pH                         -0.685521          0.247132    -0.548681
# sulphates                   0.190178         -0.256904     0.325422
# alcohol                    -0.061216         -0.197714     0.104459
# quality                     0.119190         -0.395077     0.226920
# free sulphur dioxide       -0.139707         -0.020591    -0.047983
# ...

# %%
# Plotting graphs of the respective columns to give more insight on the DataFrame
# Mean filled DataFrame without duplicates

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 10))

# Plotting the data
for i in range(3):
    for j in range(4):
        column = dataset_duplicates.columns[i*4+j]
        axs[i, j].hist(dataset_duplicates[column], bins=50, color='orange', alpha=0.7)
        axs[i, j].set_title(f'Histogram for {column}')

plt.tight_layout()
plt.show()

# %%
# This plot is for the mean filled DataFrame with duplicates

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 10))

# Plotting the data
for i in range(3):
    for j in range(4):
        column = x.columns[i*4+j]
        axs[i, j].hist(x[column], bins=50, color='blue', alpha=0.7)
        axs[i, j].set_title(f'Histogram for {column}')

plt.tight_layout()
plt.show()

# %%
# For the mode filled DataFrame with duplicates

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 10))

# Plotting the data
for i in range(3):
    for j in range(4):
        column = y.columns[i*4+j]
        axs[i, j].hist(y[column], bins=50, color='green', alpha=0.7)
        axs[i, j].set_title(f'Histogram for {column}')

plt.tight_layout()
plt.show()

# %%
# For the median filled DataFrame with duplicates

# %%
fig, axs = plt.subplots(3, 4, figsize=(15, 10))

# Plotting the data
for i in range(3):
    for j in range(4):
        column = z.columns[i*4+j]
        axs[i, j].hist(z[column], bins=50, color='red', alpha=0.7)
        axs[i, j].set_title(f'Histogram for {column}')

plt.tight_layout()
plt.show()

# %%
# Scatter diagrams of the columns of the mean filled DataFrame taken in pairs 
# First, fixed acidity and volatile acidity

# %%
plt.scatter(x['fixed acidity'], x['volatile acidity'])
plt.xlabel('fixed acidity')
plt.ylabel('volatile acidity')
plt.show()

# %%
# Second, citric acid and residual sugar

# %%
plt.scatter(x['citric acid'], x['residual sugar'])
plt.xlabel('citric acid')
plt.ylabel('residual sugar')
plt.show()

# %%
# Thirdly,chlorides and free sulfur dioxide

# %%
plt.scatter(x['chlorides'], x['free sulfur dioxide'])
plt.xlabel('chlorides')
plt.ylabel('free sulfur dioxide')
plt.show()

# %%
# Taking total sulfur dioxide and density

# %%
plt.scatter(x['total sulfur dioxide'], x['density'])
plt.xlabel('total sulfur dioxide')
plt.ylabel('density')
plt.show()

# %%
# Taking pH and sulphates

# %%
plt.scatter(x['pH'], x['sulphates'])
plt.xlabel('pH')
plt.ylabel('sulphates')
plt.show()

# %%
# Taking alcohol and quality

# %%
plt.scatter(x['alcohol'], x['quality'])
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.show()

# %%
# Plotting the scatter diagram of the mode filled DataFrame

# %%
plt.scatter(y['fixed acidity'], y['volatile acidity'], color='red') 
plt.xlabel('fixed acidity')
plt.ylabel('volatile acidity')
plt.show()

# %%
plt.scatter(y['citric acid'], y['residual sugar'], color='red') 
plt.xlabel('citric acid')
plt.ylabel('residual sugar')
plt.show()

# %%
plt.scatter(y['chlorides'], y['free sulfur dioxide'], color='red') 
plt.xlabel('chlorides')
plt.ylabel('free sulfur dioxide')
plt.show()

# %%
plt.scatter(y['total sulfur dioxide'], y['density'], color='red') 
plt.xlabel('total sulfur dioxide')
plt.ylabel('density')
plt.show()

# %%
plt.scatter(y['pH'], y['sulphates'], color='red') 
plt.xlabel('pH')
plt.ylabel('sulphates')
plt.show()

# %%
plt.scatter(y['alcohol'], y['quality'], color='red') 
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.show()

# %%
# Plotting the scatter diagram of the median filled DataFame

# %%
plt.scatter(z['fixed acidity'], z['volatile acidity'], color='green') 
plt.xlabel('fixed acidity')
plt.ylabel('volatile acidity')
plt.show()

# %%
plt.scatter(z['citric acid'], z['residual sugar'], color='green') 
plt.xlabel('citric acid')
plt.ylabel('residual sugar')
plt.show()

# %%
plt.scatter(z['chlorides'], z['free sulfur dioxide'], color='green') 
plt.xlabel('chlorides')
plt.ylabel('free sulfur dioxide')
plt.show()

# %%
plt.scatter(z['total sulfur dioxide'], z['density'], color='green') 
plt.xlabel('total sulfur dioxide')
plt.ylabel('density')
plt.show()

# %%
plt.scatter(z['pH'], z['sulphates'], color='green') 
plt.xlabel('pH')
plt.ylabel('sulphates')
plt.show()

# %%
plt.scatter(z['alcohol'], z['quality'], color='green') 
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.show()

# %%
# Plottin the scatter diagram of the mean filled DataFrame with the duplicates removed

# %%
plt.scatter(dataset_duplicates['fixed acidity'], dataset_duplicates['volatile acidity'], color='orange') 
plt.xlabel('fixed acidity')
plt.ylabel('volatile acidity')
plt.show()

# %%
plt.scatter(dataset_duplicates['citric acid'], dataset_duplicates['residual sugar'], color='orange') 
plt.xlabel('citric acid')
plt.ylabel('residual sugar')
plt.show()

# %%
plt.scatter(dataset_duplicates['chlorides'], dataset_duplicates['free sulfur dioxide'], color='orange') 
plt.xlabel('chlorides')
plt.ylabel('free sulfur dioxide')
plt.show()

# %%
plt.scatter(dataset_duplicates['total sulfur dioxide'], dataset_duplicates['density'], color='orange') 
plt.xlabel('total sulfur dioxide')
plt.ylabel('density')
plt.show()

# %%
plt.scatter(dataset_duplicates['pH'], dataset_duplicates['sulphates'], color='orange') 
plt.xlabel('pH')
plt.ylabel('sulphates')
plt.show()

# %%
plt.scatter(dataset_duplicates['alcohol'], dataset_duplicates['quality'], color='orange') 
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.show()

# %% [markdown]
# ### Analysis of Wine Quality Indicators
# ---
# ### Introduction
# ---
# This report analyzes various chemical properties of wines in the histograms and scatter diagrams above. Each histogram represents the distribution of a specific chemical property in the dataset of samples.
#
# ### Histogram analysis
# ---
# - I first dealt with the **mean-filled DataFrame with the duplicates removed** *(that is, 1360 rows and 12 columns)*
#   ### Fixed acidity
# - The majority of wine samples have a fixed acidity between 6 and 10.
# - There is a sharp decline in frequency as fixed acidity increases beyond 10
#
#   ### Volatile acidity
# - Most wines have volatile acidity ranging from 0.25 to 0.75.
# - Few wines exhibit volatile acidity above 1
#
#   ### Citric acid
# - A significant number of wine samples contain low levels of citric acid, particularly below 0.4.
#
#   ### Residual Sugar
# - Most wines have residual sugar close to 2.
# - The frequency decreases sharply as residual sugar increases
#
#   ### Chlorides
# - Most wines have chlorides close to 0.1.
# - The frequency decreases sharply as chlorides increase
#
#   ### Free sulfur dioxide
# - Most wines have free sulfur dioxide around 20-30.
# - The frequency decreases as free sulfur dioxide increases
#
#   ### Total sulfur dioxide
# - Most wines have total sulfur dioxide between 100-150.
# - The frequency decreases as total sulfur dioxide increases
#
#   ### Density
# - Most wines have a density just below 1.0000 with very little variation.
#
#   ### pH
# - The pH level shows a normal distribution peaking at around 3.2.
#
#   ### Sulphates
# - Most wines have sulphates slightly before reaching a value of 1.
# - The frequency decreases as sulphates increase
#
#   ### Alcohol
# - The alcohol content displays multiple peaks indicating varied alcohol content levels with significant peaks at approximately both ends (9% &14%).
#
#   ### Quality
# - The quality rating indicates two prominent peaks suggesting two common quality ratings within the dataset
#
#     ### Conclusion
#   ---
# The histograms provide insights into the chemical composition variability among wine samples. Understanding these distributions is crucial for assessing wine quality and categorines based on their chemical profiles.
#
#  Since I made the same observations as I did with subsequent histograms, the same analysis can then be made to those other histograms *(that is, the mean-filled DataFrame with duplicates, the mode-filled DataFrame with duplicates, and the median-filled DataFrame with duplicates removed )*.**Further observations might even show that, the *mode-filled DataFrame with duplicates removed* and the *median-filled DataFrame with duplicates removed* will give similar analysis**
#
#
#  ### Scatter Diagram Analysis
#
# - **First Scatter Plot**: Fixed acidity vs. Volatile acidity
#   - Analysis:
#     - The x-axis represents fixed acidity (6 to 16) and the y-axis represents volatile acidity (0.2 to 1.6).
#     - Most data points are concentrated towards the lower end of both axes, indicating lower levels of both acidities.
#     - A dense cluster exists around 8 to 10 fixed acidity and 0.4 to 0.8 volatile acidity, suggesting common levels for many wine samples.
#     - Fewer data points are scattered at higher levels of both acidities, implying fewer samples with high acid levels.
#     - Conclusion: Potential correlation observed.
#
# - **Second Scatter Plot**: Residual sugar vs. Citric acid
#   - Analysis:
#     - The x-axis represents citric acid content (0 to 1) and the y-axis represents residual sugar (0 to 16).
#     - Most data points are clustered between 0 to 0.4 citric acid and 2 to 6 residual sugar, indicating common levels in samples.
#     - Some scattered points show higher residual sugar but lower citric acid content.
#     - Conclusion: Potential correlation observed but weak due to dispersed data.
#
# - **Third Scatter Plot**: Chlorides vs. Free sulfur dioxide
#   - Analysis:
#     - The x-axis represents chlorides (0.0 to 0.6) and the y-axis represents free sulfur dioxide (0 to 70).
#     - Most data points cluster around 0.0 to 0.1 chlorides, spanning across the entire range of free sulfur dioxide.
#     - Scattered data points are visible as chlorides increase, suggesting a potential inverse correlation with free sulfur dioxide levels.
#     - Conclusion: Potential inverse correlation observed but weak due to dispersed data.
#
# - **Fourth Scatter Plot**: Total sulfur dioxide vs. Density
#   - Analysis:
#     - The x-axis represents total sulfur dioxide (0 to 300) and the y-axis represents density (0.990 to 1.004).
#     - Most data points cluster between 0 and 150 on the total sulfur dioxide scale, and between 0.996 and 1.002 on the density scale.
#     - Fewer data points are observed as total sulfur dioxide readings increase, indicating less frequency of higher readings in the dataset.
#     - Conclusion: Potential correlation observed but weak due to dispersed data.
#
# - **Fifth Scatter Plot**: pH vs. Sulphates
#   - Analysis:
#     - The x-axis represents pH (2.8 to 4.0) and the y-axis represents sulphates (0.25 to 2.00).
#     - Most data points cluster around pH value of 3.2 and sulphate value of approximately 0.5 to 1.
#     - Fewer data points occur away from this central concentration, indicating less frequent occurrences of those combinations.
#     - Conclusion: Potential correlation observed but weak due to dispersed data.
#
# - **Sixth Scatter Plot**: Alcohol content vs. Quality of wine
#   - Analysis:
#     - The x-axis represents alcohol content (approximately 9 to 15) and the y-axis represents quality (3 to 8).
#     - Most data points cluster between approximately 9 to 12 alcohol content and 5 to 7 quality.
#     - A trend suggests higher alcohol content correlates with higher quality ratings, although exceptions exist.
#     - Conclusion: Potential positive correlation observed but weak due to dispersed data.
#
# - **Conclusion**: Observations made on the mean-filled DataFrame with duplicates may apply to other variations. Further analysis might confirm consistency in the different versions of DataFrame.
